# %% [markdown]
# Представлен список чисел. Необходимо вывести элементы исходного списка, значения которых больше предыдущего элемента.
# Подсказка: элементы, удовлетворяющие условию, оформить в виде списка. Для его формирования используйте генератор.
# Пример исходного списка: [300, 2, 12, 44, 1, 1, 4, 10, 7, 1, 78, 123, 55].
# Результат: [12, 44, 4, 10, 78, 123].

# %%
numbers = [300, 2, 12, 44, 1, 1, 4, 10, 7, 1, 78, 123, 55]
new_list = [j for (i,j) in zip(numbers,numbers[1:]) if j>i]
print(new_list)
# Out:
# [12, 44, 4, 10, 78, 123]

# %% [markdown]
# Для чисел в пределах от 20 до 240 найти числа, кратные 20 или 21. Решите задание в одну строку.
# Подсказка: используйте функцию range() и генератор.

# %%
a = [num for num in range(20,240) if num%20 == 0 or num%21 == 0]
print(a)
# Out:
# [20, 21, 40, 42, 60, 63, 80, 84, 100, 105, 120, 126, 140, 147, 160, 168, 180, 189, 200, 210, 220, 231]

# %% [markdown]
# Представлен список чисел. Определите элементы списка, не имеющие повторений. Сформируйте итоговый массив чисел, соответствующих требованию. Элементы выведите в порядке их следования в исходном списке. Для выполнения задания обязательно используйте генератор.
# Пример исходного списка: [2, 2, 2, 7, 23, 1, 44, 44, 3, 2, 10, 7, 4, 11].
# Результат: [23, 1, 3, 10, 4, 11]

# %%
list_with_repetitions = [2, 2, 2, 7, 23, 1, 44, 44, 3, 2, 10, 7, 4, 11]
list_of_nums_without_repetitions = [num for num in list_with_repetitions if list_with_repetitions.count(num) == 1]
print(list_of_nums_without_repetitions)
# Out:
# [23, 1, 3, 10, 4, 11]

# %% [markdown]
# Реализовать формирование списка, используя функцию range() и возможности генератора. В список должны войти чётные числа от 100 до 1000 (включая границы). Нужно получить результат вычисления произведения всех элементов списка.
# Подсказка: использовать функцию reduce().

# %%
nums = [num for num in range(100,1001) if num%2 == 0]
from functools import reduce
product = 1 
def multiply (product,elem):
    product *= elem 
    return product
reduce(multiply,nums)
# Out:
# ...
